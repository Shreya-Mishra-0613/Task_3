# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("raw_data/train.csv")

# %% [markdown]
# # Understanding and Cleaning the Data

# %%
data.shape
# Out:
# (614, 13)

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.sample(5)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 271  LP001891   Male     Yes          0      Graduate            No
# 317  LP002036   Male     Yes          0      Graduate            No
# 174  LP001603   Male     Yes          0  Not Graduate           Yes
# 285  LP001924   Male      No          0      Graduate            No
# 539  LP002740   Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 271            11146                0.0       136.0             360.0
# 317             2058             2134.0        88.0             360.0
# 174             4344              736.0        87.0             360.0
# 285             3158             3053.0        89.0             360.0
# 539             6417                0.0       157.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 271             1.0         Urban           Y
# ...

# %%
data.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ### Insights
# Contribution of each column NULL values to the whole column data
# - Gender: 2.1%
# - Married: 0.5% (can be ignored)
# - Dependents: 2.4%
# - Self_Employed: 5.2%
# - LoanAmount: 3.6%
# - Loan_Amount_Term: 2.3%
# - Credit_History: 8.1%

# %% [markdown]
# ## Handling Missing Values

# %%
df = data

# %%
# df = df.dropna(subset=['Married']) (drops rows with NULL values in 'Married' column)
df['Married'].mode()
# Out:
# 0    Yes
# Name: Married, dtype: object

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df['Dependents'].mode()
# Out:
# 0    0
# Name: Dependents, dtype: object

# %%
df['Self_Employed'].mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
df['Loan_Amount_Term'].mode()
# Out:
# 0    360.0
# Name: Loan_Amount_Term, dtype: float64

# %%
df['Credit_History'].mode()
# Out:
# 0    1.0
# Name: Credit_History, dtype: float64

# %%
df[['Married', 'Gender', 'Dependents', 'Self_Employed', 'Loan_Amount_Term', 'Credit_History']] =df[['Married', 'Gender', 'Dependents', 'Self_Employed', 'Loan_Amount_Term', 'Credit_History']].fillna(
    df[['Married', 'Gender', 'Dependents', 'Self_Employed', 'Loan_Amount_Term', 'Credit_History']].mode().iloc[0]
)

# %%
df['LoanAmount'].mean()
# Out:
# np.float64(146.41216216216216)

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ### All the null values have been replaced

# %% [markdown]
# ### Convert float to int data type for better efficiency of code

# %%
df['CoapplicantIncome'] = df['CoapplicantIncome'].astype(int)
df['LoanAmount'] = df['LoanAmount'].astype(int)
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].astype(int)
df['Credit_History']=df['Credit_History'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    int64
#  8   LoanAmount         614 non-null    int64
#  9   Loan_Amount_Term   614 non-null    int64
#  10  Credit_History     614 non-null    int64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: int64(5), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ## Continueing with new Data, free of Missing/NULL Values

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360, 120, 240, 180,  60, 300, 480,  36,  84,  12])

# %%
df['Credit_History'].unique()
# Out:
# array([1, 0])

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000          614.00000  614.000000        614.000000
# mean       5403.459283         1621.24430  146.397394        342.410423
# std        6109.041673         2926.24876   84.037503         64.428629
# min         150.000000            0.00000    9.000000         12.000000
# 25%        2877.500000            0.00000  100.250000        360.000000
# 50%        3812.500000         1188.50000  129.000000        360.000000
# 75%        5795.000000         2297.25000  164.750000        360.000000
# max       81000.000000        41667.00000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### - Applicant's Income and LoanAmount have high positive correlation

# %% [markdown]
# # Univariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    int64
#  8   LoanAmount         614 non-null    int64
#  9   Loan_Amount_Term   614 non-null    int64
#  10  Credit_History     614 non-null    int64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: int64(5), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ## Piecharts

# %%
df['Gender'].value_counts().plot(kind='pie', autopct='%.2f%%', colors=['dodgerblue', 'deeppink'], labels=['Male', 'Female'], explode=(0.05,0))
plt.title('Gender Distribution')
plt.ylabel('') 
plt.show()

# %%
df['Married'].value_counts().plot(kind='pie', autopct='%.2f%%', colors=['red', 'green'], labels=['Yes', 'No'], explode=(0.05, 0))
plt.title('Marriage Status Distribution')
plt.ylabel('') 
plt.show()

# %%
df['Education'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0.05,0))
plt.title('Education Background')
plt.ylabel('') 
plt.show()

# %%
df['Dependents'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0, 0.025, 0.05, 0.075))
plt.title('Number of Dependents')
plt.ylabel('') 
plt.show()

# %%
df['Self_Employed'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0.05,0))
plt.title('Self-Employement Status')
plt.ylabel('') 
plt.show()

# %%
df['Property_Area'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0, 0.05, 0.07))
plt.title('Area of residence')
plt.ylabel('') 
plt.show()

# %%
df['Loan_Status'].value_counts().plot(kind='pie', autopct='%.2f%%', explode=(0.05,0))
plt.title('Loan Status')
plt.ylabel('') 
plt.show()

# %% [markdown]
# ## Distplot

# %%
sns.displot(df['ApplicantIncome'], kde=True)

# %%
sns.displot(df['CoapplicantIncome'], kind='kde')

# %%
sns.kdeplot(df['LoanAmount'])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
plt.xticks(rotation=90)
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.boxplot(df['LoanAmount'])
# Out:
# <Axes: ylabel='LoanAmount'>

# %% [markdown]
# # Bivariate and Multivariate Analysis

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                  0         146               360
# 1             4583               1508         128               360
# 2             3000                  0          66               360
# 3             2583               2358         120               360
# 4             6000                  0         141               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# ##### We can the relation between ApplicantIncome, CoapplicantIncome and LoanAmount

# %%
sns.scatterplot(x=df['ApplicantIncome'], y=df['LoanAmount'], hue=df['Gender'], style=df['Credit_History'])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
sns.barplot(x=df['Dependents'], y=df['LoanAmount'], color='orangered')
# Out:
# <Axes: xlabel='Dependents', ylabel='LoanAmount'>

# %%
sns.barplot(x=df['Gender'], y=df['LoanAmount'], color='limegreen')
# Out:
# <Axes: xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.barplot(x=df['Property_Area'], y=df['LoanAmount'], color='sienna')
# Out:
# <Axes: xlabel='Property_Area', ylabel='LoanAmount'>

# %%
sns.barplot(x=df['Loan_Status'], y=df['ApplicantIncome'])
# Out:
# <Axes: xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
sns.heatmap(pd.crosstab(df['Gender'], df['Loan_Status']), annot=True)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='Gender'>

# %%
sns.heatmap(pd.crosstab(df['Property_Area'], df['Loan_Status']), annot=True)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='Property_Area'>

# %%
df.to_csv("cleaned_data_eda.csv", index=False)
